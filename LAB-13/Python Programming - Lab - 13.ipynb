# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 13</b></center>
# <center><b><h3>Roll No.:352</b></center>
# <center><b><h3>Name:Smit Gohel</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import calculator

n1 = int(input('Enter Num 1: '))
n2 = int(input('Enter Num 2: '))

print(f'Add: {calculator.add(n1, n2)}')
print(f'Sub: {calculator.sub(n1, n2)}')
print(f'Mul: {calculator.mul(n1, n2)}')
print(f'Div: {calculator.div(n1, n2)}')
# Out:
# Enter Num 1:  40
# Enter Num 2:  5
# Add: 45
# Sub: 35
# Mul: 200
# Div: 8.0

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random
string = input('Enter String: ')

print(f'Random Character : {random.choice(string)}')
# Out:
# Enter String:  smit
# Random Character : m

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
li = list(map(int,input('Enter Elements: ').split()))

print(f'Random Element : {random.choice(li)}')
# Out:
# Enter Elements:  10 4 5
# Random Element : 5

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
random.seed(1)
random.randint(1,6)
# Out:
# 2

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
count = 0
while count != 3:
    num = random.randrange(100,999)
    if num % 5 == 0:
        count += 1
        print(num)
# Out:
# 410
# 390
# 135

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
li = []
for _ in range(100):
    li.append(random.randrange(1,101))

res = random.sample(li, k = 2)  # list return and unique select
print(f'Winner : {res[0]}')
print(f'Runner up : {res[1]}')
# Out:
# Winner : 100
# Runner up : 34

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime

print(f'Current Date : {datetime.date.today()}')
print(f'Current Time : {datetime.datetime.now()}')
# Out:
# Current Date : 2026-03-11
# Current Time : 2026-03-11 12:56:53.607622

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
d = datetime.date.today()
print(f'Current Date : {d}')

res = d + datetime.timedelta(days = -7)
print(res)
# Out:
# Current Date : 2026-03-11
# 2026-03-04

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
date1 = datetime.date.today()
date2 = datetime.date(2026,3,4)

print(f'Date diff : {date1 - date2}')
# Out:
# Enter Date :  2026 3 4
# <class 'str'>

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
d = datetime.date.today()

print(f'Day of the Week : {d.strftime("%A")}')
# Out:
# Day of the Week : Wednesday
